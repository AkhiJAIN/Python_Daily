# %% [markdown]
# # Search element in the list

# %%
mylist=[1,2,3,4,5,6,6,3,1]
elm=int(input("Enter the element for the searching purpose:"))
temp=0
for i in range(0,len(mylist)):
    if(mylist[i]==elm):
        print("Element  found")
        temp=1
        break
if(temp==0):
    print("Element is not found")
# Out:
# Element  found

# %%
ist=[1,2,3,4,5,6,6,3,1]
elm=int(input("Enter the element for the searching purpose:"))
if(elm in mylist):
    print("The elemet is found")
else:
    print("NO such elemnt")
# Out:
# The elemet is found
