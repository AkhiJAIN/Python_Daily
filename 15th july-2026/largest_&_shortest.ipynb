# %%
list=[1,23,45,6,7,2]
list.sort()
print(f"Smallest number is {list[0]} and the largest number is {list[-1]}")
# Out:
# Smallest number is 1 and the largest number is 45

# %%
list=[1,23,45,6,7,2]
print(f"Smallest number is {max(list)} and the largest number is {min(list)}")
# Out:
# Smallest number is 45 and the largest number is 1
