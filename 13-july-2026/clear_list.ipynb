# %% [markdown]
# ## Clear the given list

# %%
mylist=[1,2,3,45,6,7]
print("My list before clearing:",mylist)
mylist.clear()
print("My list after clearing:",mylist)
# Out:
# My list before clearing: [1, 2, 3, 45, 6, 7]
# My list after clearing: []
