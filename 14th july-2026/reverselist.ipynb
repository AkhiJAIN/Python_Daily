# %%
mylist=[12,5,7,89,56]
print("My list before revsering:",mylist)
print("Printing the list in the sorted format")
mylist.sort()
mylist.reverse()
print("My list after reverse:",mylist)
# Out:
# My list before revsering: [12, 5, 7, 89, 56]
# Printing the list in the sorted format
# My list after reverse: [89, 56, 12, 7, 5]

# %%
mylist=[12,5,7,89,56]
print("My list before revsering:",mylist)
mylist2=mylist[::-1]
print("My list after reverse:",mylist2)
# Out:
# My list before revsering: [12, 5, 7, 89, 56]
# My list after reverse: [56, 89, 7, 5, 12]
