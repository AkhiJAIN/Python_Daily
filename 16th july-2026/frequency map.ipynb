# %%
nums=[1,2,3,4,5,6,3,2,4,5,7,8,9]
fre_map={}
for i in range(0,len(nums)):
    if nums[i] in fre_map:
        fre_map[nums[i]]+=1
    else:
        fre_map[nums[i]]=1
print(fre_map[3])
print(fre_map)
# Out:
# 2
# {1: 1, 2: 2, 3: 2, 4: 2, 5: 2, 6: 1, 7: 1, 8: 1, 9: 1}

# %%
nums=["A","b","c","d","a","b"]
fre_map={}
for i in range(0,len(nums)):
    if nums[i] in fre_map:
        fre_map[nums[i]]+=1
    else:
        fre_map[nums[i]]=1
print(fre_map)
# Out:
# {'A': 1, 'b': 2, 'c': 1, 'd': 1, 'a': 1}
